# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv

# Add the necessary paths
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))

# project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))

# add repo root (../ from notebooks/)
repo_root = (Path.cwd() / "..").resolve()
# repo_root = Path(__file__).resolve().parents[1]   

if str(repo_root) not in sys.path:
    sys.path.append(str(repo_root))

print(repo_root)

from src.data.email_analyzer import EmailAnalyzer

# load_dotenv()
from constants import ACTIVE_PROJECT

celine_EmailAnalyzer = EmailAnalyzer(db_path=f"{repo_root}/data/Projects/{ACTIVE_PROJECT}/celinev3.duckdb")
# Out:
# /Users/julienrm/Workspace/olkoa

# %%
celine_df = celine_EmailAnalyzer.get_app_dataframe_agg_recipients()
celine_df.head(2)
# Out:
#                                           message_id                date  \
# 0  <c9a9e4966d1ec2c1db7457586c149f60@histoirecolo... 2024-02-01 11:04:53
# 1     <202429010801.8md47fp0l2robj@sib.wikimedia.fr> 2024-01-29 08:01:51
#
#                              from               recipient_email  \
# 0  contact2@histoirecoloniale.net     hco-info@lists.riseup.net
# 1               info@wikimedia.fr  celine.guyon@archivistes.org
#
#                                              subject  \
# 0  [hco-info] Archives, loi, révolutionnaire et e...
# 1  L'observatoire de l'open content vous présente...
#
#                                                 body  \
# 0  seconde édition de janvier\nLa France et les a...
# 1  L'observatoire de l'open content vous présente...
#
#                     attachments  has_attachments direction       mailbox  \
# 0  [ATT00001.txt, fdf03d7b.png]             True  received  celine Guyon
# 1                            []            False  received  celine Guyon
#
#    mailbox_name
# 0  celine Guyon
# 1  celine Guyon

# %%
celine_df.direction.value_counts()
# Out:
# direction
# received    13865
# sent         5272
# Name: count, dtype: int64

# %%
joel_EmailAnalyzer = EmailAnalyzer(db_path=f"{repo_root}/data/Projects/joel_sample_v1/joel_sample_v1.duckdb")
joel_df = joel_EmailAnalyzer.get_app_dataframe_agg_recipients()
joel_df.direction.value_counts()
# Out:
# direction
# received    4260
# Name: count, dtype: int64

# %%
dino_EmailAnalyzer = EmailAnalyzer(db_path=f"{repo_root}/data/Projects/dinodelanight/dino.duckdb")

dino_df = dino_EmailAnalyzer.get_app_dataframe_agg_recipients()
dino_df.head(2)
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[33], line 3
#       1 dino_EmailAnalyzer = EmailAnalyzer(db_path=f"{repo_root}/data/Projects/dinodelanight/dino.duckdb")
# ----> 3 dino_df = dino_EmailAnalyzer.get_app_dataframe_agg_recipients()
#       4 dino_df.head(2)
#
# File ~/Workspace/olkoa/src/data/email_analyzer.py:791, in EmailAnalyzer.get_app_dataframe_agg_recipients(self, mailbox, limit)
#     788     query += f" LIMIT {limit}"
#     790 # Execute the query and convert to DataFrame
# --> 791 df = conn.execute(query).df()
#     793 # Convert timestamps to proper datetime format
#     794 if 'date' in df.columns and not pd.api.types.is_datetime64_any_dtype(df['date']):
#
# CatalogException: Catalog Error: Table with name receiver_emails does not exist!
# Did you mean "pg_prepared_statements"?
#
# LINE 41:             receiver_emails re
#                      ^
